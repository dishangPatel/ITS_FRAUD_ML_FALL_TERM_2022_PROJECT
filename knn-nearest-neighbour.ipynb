# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/trainnntesttt/preprocessedTest (2).csv
# /kaggle/input/trainnntesttt/preprocessesTrain.csv
# /kaggle/input/its-a-fraud/train.csv
# /kaggle/input/its-a-fraud/test.csv
# /kaggle/input/its-a-fraud/mock_submission.csv

# %%
train=pd.read_csv('../input/trainnntesttt/preprocessesTrain.csv')
test = pd.read_csv('../input/trainnntesttt/preprocessedTest (2).csv')

# %%
def changeDType(df,flag=False):
    
    if(flag):
        numericDtype = ['int32','int64','float64','float32']
    
    for i in df.columns:
        if (df[i].dtype == 'int64' or df[i].dtype == 'int32'):
            df[i] = pd.to_numeric(df[i],downcast='integer')
        
        if (df[i].dtype == 'float64' or df[i].dtype == 'float32'):
            df[i] = pd.to_numeric(df[i],downcast='float')

# %%
changeDType(train,False)
changeDType(test,False)

# %%
x=train.drop(['isFraud'],axis=1)
x = x - x.min()/x.max()-x.min()

# %%
y=train['isFraud']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9) #Split the dataset

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
error_rate = []
for i in range(40,60):
    knn = KNeighborsClassifier(n_neighbors=i,n_jobs=-1)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24/3962909214.py in <module>
#       5     knn = KNeighborsClassifier(n_neighbors=i,n_jobs=-1)
#       6     knn.fit(X_train,y_train)
# ----> 7     pred_i = knn.predict(X_test)
#       8     error_rate.append(np.mean(pred_i != y_test))
#       9
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     212             Class labels for each data sample.
#     213         """
# --> 214         neigh_dist, neigh_ind = self.kneighbors(X)
#     215         classes_ = self.classes_
#     216         _y = self._y
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     757                     metric=self.effective_metric_,
#     758                     n_jobs=n_jobs,
# --> 759                     **kwds,
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 100
neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
print("Accuracy of model at K=4 is",metrics.roc_auc_score(y_test, Pred_y))
# Out:
# Accuracy of model at K=4 is 0.9686241610738255
# Accuracy of model at K=4 is 0.5108222620828541

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 20
neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
print("Accuracy of model at K=4 is",metrics.roc_auc_score(y_test, Pred_y))
# Out:
# Accuracy of model at K=4 is 0.9711409395973154
# Accuracy of model at K=4 is 0.5621254997526172

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 12
neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
print("Accuracy of model at K=4 is",metrics.roc_auc_score(y_test, Pred_y))
# Out:
# Accuracy of model at K=4 is 0.9720573051109964
# Accuracy of model at K=4 is 0.5861297942956568

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 80
neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
print("Accuracy of model at K=4 is",metrics.roc_auc_score(y_test, Pred_y))
# Out:
# Accuracy of model at K=4 is 0.968830665978317
# Accuracy of model at K=4 is 0.5130859217174297

# %%
#best
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 50
neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
print("Accuracy of model at K=4 is",metrics.roc_auc_score(y_test, Pred_y))
# Out:
# Accuracy of model at K=4 is 0.9693469282395457
# Accuracy of model at K=4 is 0.5241376029921292

# %%
test = test - test.min()/test.max()-test.min()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 200
neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
print("Accuracy of model at K=4 is",metrics.roc_auc_score(y_test, Pred_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24/2561948024.py in <module>
#       2 from sklearn import metrics
#       3 k = 200
# ----> 4 neigh = KNeighborsClassifier(n_neighbors = k, n_jobs=-1).fit(X_train,y_train)
#       5 Pred_y = neigh.predict(X_test)
#       6 print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
#
# NameError: name 'X_train' is not defined

# %%
y_final=knn.predict(test)

# %%
result = pd.DataFrame(y_final)

# %%
result.to_csv('./result_knn_try.csv')

# %%
result.shape
# Out:
# (147635, 1)
